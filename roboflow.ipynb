# %%
import requests
import cv2
from PIL import Image
import tempfile

def extract_first_frame(video_path):
    cap = cv2.VideoCapture(video_path)
    ret, frame = cap.read()
    cap.release()
    if ret:
        return frame
    else:
        raise ValueError("Failed to read the video.")

def convert_to_rgb(frame):
    return cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

def save_frame_as_image(frame):
    pil_image = Image.fromarray(frame)
    temp_file = tempfile.NamedTemporaryFile(delete=False, suffix='.jpg')
    pil_image.save(temp_file, 'JPEG')
    return temp_file.name

def send_scan_to_roboflow(video_path):
    API_URL = "https://detect.roboflow.com/human-activity-recognition-0lqsi/1"
    API_KEY = "Ax4LhZgUTmUL8cGMbYUU"

    
    frame = extract_first_frame(video_path)
    rgb_frame = convert_to_rgb(frame)
    image_path = save_frame_as_image(rgb_frame)
    
    try:
        with open(image_path, 'rb') as image_file:
            response = requests.post(
                API_URL,
                files={"file": image_file},
                params={"api_key": API_KEY}
            )
            response.raise_for_status()
            result = response.json()
            # print("Roboflow Result:", result)
            return result

    except requests.RequestException as e:
        return {"error": f"API request failed: {str(e)}"}

# %%
video_path = "videos/sitting.mp4"  # Replace with your video path
result = send_scan_to_roboflow(video_path)
print(result)
# predictions = result.get("predictions", [])
# print(predictions[0].get("class"))
# Out:
# {'error': 'API request failed: HTTPSConnectionPool(host=\'detect.roboflow.com\', port=443): Max retries exceeded with url: /human-activity-recognition-0lqsi/1?api_key=Ax4LhZgUTmUL8cGMbYUU (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001A01E5CDB90>: Failed to resolve \'detect.roboflow.com\' ([Errno 11001] getaddrinfo failed)"))'}

# %%
video_path = "videos/walking.mp4"  # Replace with your video path
result = send_scan_to_roboflow(video_path)
# print(result)
predictions = result.get("predictions", [])
print(predictions[0].get("class"))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[48], line 5
#       3 # print(result)
#       4 predictions = result.get("predictions", [])
# ----> 5 print(predictions[0].get("class"))
#
# IndexError: list index out of range

# %%
video_path = "videos/eating.mp4"  # Replace with your video path
result = send_scan_to_roboflow(video_path)
# print(result)
predictions = result.get("predictions", [])
print(predictions[0].get("class"))
# Out:
# Eating

# %%
video_path = "videos/running.mp4"  # Replace with your video path
result = send_scan_to_roboflow(video_path)
# print(result)
predictions = result.get("predictions", [])
print(predictions[0].get("class"))
# Out:
# Running

# %%
video_path = "videos/sleeping.mp4"  # Replace with your video path
result = send_scan_to_roboflow(video_path)
# print(result)
predictions = result.get("predictions", [])
print(predictions[0].get("class"))
# Out:
# Sleeping
